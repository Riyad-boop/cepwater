# %% [markdown]
# # GRASS setup in Windows
#  - Note: Setup with QGIS does not work because the grass executable does not exist. A standalone installation of GRASS is required.
#
# ## Step 1: Test and install six module if not installed
# - pip install six
#
# ## Step 2: Add grass path to the site-packages
# - Go to your python site-packages folder and add a new file named grass.pth
# - Then write these two lines in the file
# ```
# C:\Program Files\GRASS GIS 7.8\etc\python
# C:\Program Files\GRASS GIS 7.8\bin
# ```
#
# - Now you can import grass in your python script
#
# ## Step 3: If GRASS still not recognised by IDE. go to environment variables in Windows and add new system variables
# - GISBASE C:\Program Files\GRASS GIS 7.8
# - GISRC E:\AD4GD\Water\grassdata (this is your grassdata folder)
# - Path C:\Program Files\GRASS GIS 7.8\bin (edit path and add this)

# %%
import os

# get environment variables
matches_directory = './matches.txt'
output_directory = os.environ['GRASS_OUTPUT_DIRECTORY']
gisdb = os.environ['GRASS_GISDB']
location = os.environ['GRASS_LOCATION']
mapset = os.environ['GRASS_MAPSET']
grass7bin_win = os.environ['GRASS_WIN_EXECUTABLE']

# %%
# reference: https://grasswiki.osgeo.org/wiki/Working_with_GRASS_without_starting_it_explicitly
import os
import sys
import subprocess

########### SOFTWARE
# we assume that the GRASS GIS start script is available and in the PATH
# query GRASS 7 itself for its GISBASE
grass7bin = grass7bin_win

# query GRASS 7 itself for its GISBASE
startcmd = [grass7bin, '--config', 'path']

p = subprocess.Popen(startcmd, shell=False,
                     stdout=subprocess.PIPE, stderr=subprocess.PIPE)
out, err = p.communicate()
if p.returncode != 0:
    print >>sys.stderr, "ERROR: Cannot find GRASS GIS 7 start script (%s)" % startcmd
    sys.exit(-1)
gisbase = out.decode('utf-8').strip('\n\r')

# Set GISBASE environment variable
os.environ['GISBASE'] = gisbase
# the following not needed with trunk
os.environ['PATH'] += os.pathsep + os.path.join(gisbase, 'extrabin')
# add path to GRASS addons
home = os.path.expanduser("~")
os.environ['PATH'] += os.pathsep + os.path.join(home, '.grass7', 'addons', 'scripts')

# define GRASS-Python environment
gpydir = os.path.join(gisbase, "etc", "python")
sys.path.append(gpydir)

# Set GISDBASE environment variable
os.environ['GISDBASE'] = gisdb
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 14
#      11 # query GRASS 7 itself for its GISBASE
#      12 startcmd = [grass7bin, '--config', 'path']
# ---> 14 p = subprocess.Popen(startcmd, shell=False,
#      15                      stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#      16 out, err = p.communicate()
#      17 if p.returncode != 0:
#
# File C:\Python312\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File C:\Python312\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1536 # Start the process
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)
#    1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#    1553     self._close_pipe_fds(p2cread, p2cwrite,
#    1554                          c2pread, c2pwrite,
#    1555                          errread, errwrite)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified

# %% [markdown]
# # Start GRASS Session

# %%
# Set GISDBASE environment variable
os.environ['GISDBASE'] = gisdb
 
# import GRASS Python bindings (see also pygrass)
import grass.script as gscript
import grass.script.setup as gsetup
 
###########
# launch session
gsetup.init(gisbase,
            gisdb, location, mapset)
 
# check is everything is alright (should return gisdb, location and mapset)
print(gscript.gisenv())

# %% [markdown]
# # Single thread mode (502 mins)

# %%
#!/usr/bin/env python3

import grass.script as gscript
matches_directory = 'C:\\Users\\riyad\\Documents\\GitHub\\cepwater\\matches.txt'
output_directory = 'C:\\Users\\riyad\\Downloads\\Work\\cep_output'

class SingleTileProcessor():
    def __init__(self, matches_file_path, output_dir):
        self.matches = self.read_matches_file_to_dict(matches_file_path)
        self.output_dir = output_dir

    def read_matches_file_to_dict(self,file_path):
        matches = {}
        with open(file_path, 'r') as f:
            for line in f:
                line = line.strip()
                if line:
                    key, value = line.split()
                    matches[key] = value
        return matches

    def process_tiles(self, matches:dict):
        # iterate over the matches dictionary
        for key, value in matches.items():
            filename = output_directory + '\\' + key.split('\\')[-1].split('.')[0] + '.csv'
            # import the raster (value) into the mapset
            gscript.run_command('r.in.gdal', input=value, output='py_cep')
            # set the region to the raster
            gscript.run_command('g.region', raster='py_cep')
            # run r.stats to get the statistics (flags: a = print area, n = no nulls)
            gscript.run_command('r.stats', flags='an', input='py_cep', separator='comma', output=filename)
            # delete the imported rasters
            gscript.run_command('g.remove', flags='f', type='raster', name='py_cep')

def main():
    tileProcessor = SingleTileProcessor(matches_directory, output_directory)
    tileProcessor.process_tiles(tileProcessor.matches)

if __name__ == '__main__':
    main()

# %% [markdown]
# # Mutli-Threading: 8 threads (XX mins)
# - Note multi-threading may not work in the IDE so run the script in a GRASS session instead

# %%
import multiprocessing

# %%
import multiprocessing
matches_directory = 'C:\\Users\\riyad\\Documents\\GitHub\\cepwater\\matches.txt'
output_directory = 'C:\\Users\\riyad\\Downloads\\Work\\cep_output'

class MultiTileProcessor:

    def __init__(self, matches_file_path, output_dir, threads=2):
        self.matches = self.read_matches_file_to_dict(matches_file_path)
        self.output_dir = output_dir
        self.threads = threads

    def read_matches_file_to_dict(self,file_path):
        matches = {}
        with open(file_path, 'r') as f:
            for line in f:
                line = line.strip()
                if line:
                    key, value = line.split()
                    matches[key] = value
        return matches
    
    def import_raster(self, match):
        key,value = match
        pid = multiprocessing.current_process().pid
        cep_raster_name = 'py_cep_{}'.format(pid)
        # remove the combined raster if it already exists
        gscript.run_command('g.remove', flags='f', type='raster', name=cep_raster_name)
        # import the raster (value) into the mapset
        gscript.run_command('r.in.gdal', input=value, output=cep_raster_name)
        print('Imported: {}'.format(value))
        filename = key.split('\\')[-1].split('.')[0] + '.csv'
        return cep_raster_name,filename
    
    def process_rasters(self,outputs):
        for output in outputs:
            for cep_raster_name,filename in output:
                filename = output_directory + '\\' + filename
                #set region to the raster
                gscript.run_command('g.region', raster=cep_raster_name)
                print('Region set to: {}'.format(cep_raster_name))
                # run r.stats to get the statistics (flags: a = print area, n = no nulls)
                gscript.run_command('r.stats', flags='an', input=cep_raster_name, output=filename)
                print('Statistics written to: {}'.format(filename))
                # delete the imported rasters
                gscript.run_command('g.remove', flags='f', type='raster', name=cep_raster_name)
                print('Removed: {}'.format(cep_raster_name))

    def process_tiles(self):
        #split matches into chunks depending on the number of threads (4-8 threads is optimal for most systems)
        chunks = [dict(list(self.matches.items())[i:i + self.threads]) for i in range(0, len(self.matches), self.threads)]
        # test with 8 chunks (8 threads)
        chunks = chunks[:8]
        for chunk in chunks:
            print('Processing Chunk: {}'.format(chunk))
            outputs = []
            #import rasters in parallel
            with multiprocessing.Pool(self.threads) as pool:
                outputs.append(pool.map(self.import_raster, chunk.items()))

            #process rasters in on main thread to avoid conflicts with GRASS region settings
            self.process_rasters(outputs)        
        
    
    
def main():
    tileProcessor = MultiTileProcessor(matches_dir, output_dir, threads=8)
    tileProcessor.matches

if __name__ == '__main__':
    main()
# Out:
# {'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_0N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_0N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_10N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_10N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_10S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_10S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_20N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_20N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_20S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_20S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_30N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_30N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_30S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_30S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_40N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_40N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_40S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_40S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_50N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_50N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_50S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_50S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_60N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_60N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_60S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_60S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_70N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_70N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_70S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_70S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_80N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_80N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_80S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_80S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\0E_90N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\0E_90N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_0N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_0N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_10N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_10N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_10S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_10S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_20N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_20N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_20S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_20S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_30N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_30N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_30S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_30S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_40N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_40N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_40S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_40S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_50N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_50N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_50S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_50S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_60N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_60N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_60S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_60S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_70N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_70N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_70S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_70S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_80N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_80N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_80S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_80S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100E_90N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100E_90N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_0N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_0N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_10N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_10N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_10S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_10S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_20N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_20N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_20S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_20S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_30N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_30N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_30S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_30S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_40N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_40N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_40S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_40S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_50N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_50N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_50S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_50S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_60N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_60N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_60S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_60S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_70N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_70N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_70S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_70S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_80N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_80N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_80S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_80S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\100W_90N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\100W_90N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_0N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_0N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_10N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_10N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_10S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_10S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_20N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_20N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_20S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_20S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_30N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_30N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_30S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_30S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_40N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_40N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_40S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_40S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_50N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_50N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_50S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_50S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_60N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_60N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_60S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_60S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_70N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_70N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_70S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_70S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_80N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_80N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_80S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_80S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10E_90N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10E_90N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_0N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_0N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_10N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_10N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_10S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_10S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_20N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_20N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_20S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_20S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_30N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_30N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_30S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_30S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_40N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_40N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_40S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_40S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_50N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_50N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_50S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_50S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_60N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_60N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_60S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_60S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_70N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_70N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_70S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_70S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_80N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_80N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_80S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_80S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\10W_90N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\10W_90N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_0N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_0N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_10N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_10N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_10S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_10S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_20N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_20N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_20S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_20S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_30N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_30N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_30S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_30S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_40N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_40N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_40S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_40S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_50N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_50N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_50S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_50S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_60N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_60N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_60S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_60S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_70N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_70N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_70S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_70S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_80N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_80N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_80S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_80S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110E_90N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110E_90N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_0N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_0N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_10N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_10N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_10S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_10S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_20N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_20N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_20S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_20S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_30N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_30N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_30S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_30S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_40N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_40N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_40S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_40S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_50N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_50N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_50S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_50S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_60N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_60N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_60S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_60S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_70N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_70N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_70S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_70S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_80N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_80N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_80S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_80S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\110W_90N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\110W_90N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_0N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_0N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_10N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_10N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_10S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_10S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_20N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_20N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_20S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_20S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_30N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_30N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_30S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_30S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_40N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_40N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_40S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_40S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_50N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_50N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_50S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_50S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_60N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_60N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_60S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_60S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_70N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_70N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_70S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_70S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_80N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_80N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_80S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_80S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120E_90N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120E_90N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_0N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_0N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_10N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_10N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_10S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_10S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_20N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_20N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_20S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_20S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_30N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_30N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_30S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_30S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_40N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_40N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_40S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_40S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_50N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_50N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_50S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_50S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_60N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_60N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_60S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_60S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_70N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_70N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_70S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_70S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_80N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_80N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_80S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_80S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\120W_90N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\120W_90N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_0N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_0N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_10N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_10N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_10S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_10S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_20N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_20N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_20S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_20S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_30N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_30N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_30S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_30S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_40N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_40N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_40S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_40S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_50N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_50N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_50S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_50S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_60N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_60N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_60S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_60S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_70N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_70N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_70S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_70S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_80N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_80N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_80S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_80S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130E_90N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130E_90N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130W_0N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130W_0N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130W_10N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130W_10N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130W_10S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130W_10S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130W_20N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130W_20N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130W_20S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130W_20S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130W_30N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130W_30N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130W_30S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130W_30S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130W_40N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130W_40N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130W_40S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130W_40S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130W_50N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130W_50N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130W_50S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130W_50S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130W_60N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130W_60N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130W_60S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130W_60S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130W_70N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130W_70N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130W_70S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130W_70S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130W_80N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130W_80N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\130W_80S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\130W_80S.tiff',
# ...
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80E_30S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80E_30S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80E_40N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80E_40N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80E_40S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80E_40S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80E_50N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80E_50N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80E_50S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80E_50S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80E_60N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80E_60N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80E_60S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80E_60S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80E_70N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80E_70N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80E_70S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80E_70S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80E_80N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80E_80N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80E_80S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80E_80S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80E_90N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80E_90N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_0N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_0N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_10N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_10N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_10S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_10S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_20N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_20N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_20S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_20S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_30N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_30N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_30S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_30S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_40N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_40N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_40S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_40S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_50N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_50N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_50S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_50S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_60N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_60N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_60S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_60S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_70N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_70N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_70S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_70S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_80N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_80N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_80S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_80S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\80W_90N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\80W_90N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_0N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_0N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_10N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_10N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_10S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_10S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_20N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_20N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_20S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_20S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_30N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_30N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_30S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_30S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_40N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_40N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_40S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_40S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_50N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_50N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_50S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_50S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_60N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_60N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_60S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_60S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_70N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_70N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_70S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_70S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_80N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_80N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_80S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_80S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90E_90N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90E_90N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_0N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_0N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_10N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_10N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_10S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_10S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_20N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_20N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_20S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_20S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_30N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_30N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_30S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_30S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_40N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_40N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_40S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_40S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_50N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_50N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_50S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_50S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_60N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_60N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_60S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_60S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_70N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_70N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_70S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_70S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_80N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_80N.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_80S.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_80S.tiff',
#  'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\JRC\\\\cep_oecm202302\\\\cep_oecm202302\\\\tiles\\90W_90N.tiff': 'C:\\\\Users\\\\riyad\\\\Documents\\\\Subjects\\\\WaterQualityContract\\\\GSW\\\\data\\90W_90N.tiff'}

# %%
### ONLY UNCOMMENT WHEN RUNNING IN GRASS ENVIRONMENT ###
##!/usr/bin/env python3

# import grass.script as gscript
# import multiprocessing

# # define variables using absolute paths
# matches_file_path = 'C:\\Users\\riyad\\Documents\\GitHub\\AD4GD_Water\\matches.txt'
# output_dir = 'C:\\Users\\riyad\\Downloads\\Work\\output'
### ONLY UNCOMMENT WHEN RUNNING IN GRASS ENVIRONMENT ###

class MultiTileProcessor:

    def __init__(self, matches_file_path, output_dir, threads=2):
        self.matches = self.read_matches_file_to_dict(matches_file_path)
        self.output_dir = output_dir
        self.threads = threads
        
    def read_matches_file_to_dict(self,file_path):
        matches = {}
        with open(file_path, 'r') as f:
            for line in f:
                line = line.strip()
                if line:
                    key, value = line.split()
                    matches[key] = value
        return matches

    def import_raster(self, match):
        key,value = match
        pid = multiprocessing.current_process().pid
        water_raster = 'py_water_{}'.format(pid)
        cep_raster = 'py_cep_{}'.format(pid)
        combined_raster_names = water_raster + ',' + cep_raster
        # remove the combined raster if it already exists
        gscript.run_command('g.remove', flags='f', type='raster', name=combined_raster_names)
        # import the raster (key) into the mapset
        gscript.run_command('r.in.gdal', input=key, output=water_raster)
        print('Imported: {}'.format(key))
        # import the raster (value) into the mapset
        gscript.run_command('r.in.gdal', input=value, output=cep_raster)
        print('Imported: {}'.format(value))
        filename = key.split('\\')[-1].split('.')[0] + '.csv'
        return combined_raster_names,water_raster,filename
    
    def process_rasters(self,outputs):
        for output in outputs:
            for combined_raster_names,water_raster,filename in output:
                filename = output_directory + '\\' + filename
                #set region to the raster
                gscript.run_command('g.region', raster=water_raster)
                print('Region set to: {}'.format(water_raster))
                # run r.stats to get the statistics (flags: a = print area, n = no nulls)
                gscript.run_command('r.stats', flags='an', input=combined_raster_names, separator='comma', output=filename)
                print('Statistics written to: {}'.format(filename))
                # delete the imported rasters
                gscript.run_command('g.remove', flags='f', type='raster', name=combined_raster_names)
                print('Removed: {}'.format(combined_raster_names))

    
    def process_tiles(self):
        #split matches into chunks depending on the number of threads (4-8 threads is optimal for most systems)
        chunks = [dict(list(self.matches.items())[i:i + self.threads]) for i in range(0, len(self.matches), self.threads)]
        # test with 8 chunks (8 threads)
        chunks = chunks[:8]
        for chunk in chunks:
            print('Processing Chunk: {}'.format(chunk))
            outputs = []
            #import rasters in parallel
            with multiprocessing.Pool(self.threads) as pool:
                outputs.append(pool.map(self.import_raster, chunk.items()))

            #process rasters in on main thread to avoid conflicts with GRASS region settings
            self.process_rasters(outputs)                


# def main():
#     tileProcessor = MultiTileProcessor(matches_directory, output_directory, threads=8)
#     tileProcessor.process_tiles()

# if __name__ == '__main__':
#     main()
